# %% [markdown]
# <a href="https://colab.research.google.com/github/Dongre111/Dongre111/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as ens
import matplotlib.pyplot as plt

# %%
HD = pd.read_csv('/content/california_housing_test.csv')

# %%
HD
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
HD.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
HD.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
HD.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
HD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
HD.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
HD['housing_median_age'].mad()
# Out:
# <ipython-input-12-4422172e4740>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   HD['housing_median_age'].mad()
# 10.52336177777778

# %%
HD['median_income'].mad()
# Out:
# <ipython-input-13-fa44df7b78e3>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   HD['median_income'].mad()
# 1.3624588452

# %%
HD['median_house_value'].mad()
# Out:
# <ipython-input-14-491c8d3e59d5>:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   HD['median_house_value'].mad()
# 89459.35378333334

# %%
# Standard Deviation

# %%
std = HD['median_house_value'].std()

# %%
std
# Out:
# 113119.68746964628

# %%
std**2
# Out:
# 12796063693.23045

# %%
HD['median_house_value'].var()
# Out:
# 12796063693.23045

# %%
HD['median_house_value'].plot(kind='kde')
plt.show()

# %%
HD['median_house_value'].plot(kind='box')
plt.show()

# %%
HD['median_house_value'].mean()
# Out:
# 205846.275

# %%
std
# Out:
# 113119.68746964628

# %%
var=HD['median_house_value'].var()

# %%
var
# Out:
# 12796063693.23045

# %%
std**2
# Out:
# 12796063693.23045

# %% [markdown]
# Standard error

# %%
standard_error=std/np.sqrt(len(HD))

# %%
standard_error
# Out:
# 2065.2734841686583

# %%
D1 = pd.DataFrame({'stu_A':[28,25,26,23],
                   'stu_B':[18,28,16,13]})

# %%
D1
# Out:
#    stu_A  stu_B
# 0     28     18
# 1     25     28
# 2     26     16
# 3     23     13
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# D1['stu_A'].plot(kind='hist', bins=20, title='stu_A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# D1['stu_B'].plot(kind='hist', bins=20, title='stu_B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# D1.plot(kind='scatter', x='stu_A', y='stu_B', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
Q3 = HD['total_rooms'].quantile(0.25)

# %%
Q3
# Out:
# 1401.0

# %%
Q2 = HD['total_rooms'].quantile(0.50)

# %%
Q2
# Out:
# 2106.0

# %%
Q1 = HD['total_rooms'].quantile(0.75)

# %%
Q1
# Out:
# 3129.0

# %%
IQR = Q1-Q3

# %%
IQR
# Out:
# 1728.0

# %%
MAX = HD['total_rooms'].max()

# %%
MAX
# Out:
# 30450.0

# %%
min = HD['total_rooms'].min()

# %%
min
# Out:
# 6.0

# %%
range =MAX-min

# %%
range
# Out:
# 30444.0
